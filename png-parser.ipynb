# %% [markdown]
# # PNG Parser in pure python
#
# A monolithic, a bit bloated, questionable implementations, and non performant png data structure parser built in python 3.10 with minimal external library dependencies.
#
# References:
# - [libpng file specification](http://www.libpng.org/pub/png/spec/1.2/PNG-Structure.html)
# - [w3c file specification](https://www.w3.org/TR/2003/REC-PNG-20031110/)
# - [other non-standard png chunk type tags reference (ExifTools)](https://exiftool.org/TagNames/PNG.html)

# %% [markdown]
# ## Imports

# %%
from re import compile as re_compile
from pathlib import Path
from dataclasses import dataclass, field
from io import BytesIO
import struct
import os
import time
# import logging

# %% [markdown]
# ## Constants

# %% [markdown]
# ### png and parser definitions

# %%
PNG_SIGNATURE = bytearray([137, 80, 78, 71, 13, 10, 26, 10])
NULL_SEP = b'\0' # or b'\x00'

# list of sRGB chunk intent values
LS_PNG_CT_sRGB_INTENT_V = [
    'Perceptual',
    'Relative colorimetric',
    'Saturation',
    'Absolute colorimetric'
]

# %% [markdown]
# ### Optional options

# %%
VERBOSE = True

SAVE_PRINT_STDOUT = True
SAVE_PRINT_PRUNE = True
SAVE_PRINT_FNAME = 'stdout.txt'

# %% [markdown]
# ### Tests definitions
#
# *keep in mind* this is not unit test, it just a generic test to prove the ability to parse with suite of png test file

# %% [markdown]
# #### > Schaik Standard Test Suite
#
# Test used are suites provided by Schaik at [schaik.com]([schaik.com](http://www.schaik.com/pngsuite/))
# / [suite webpage](http://www.libpng.org/pub/png/pngsuite.html)
# / [license](http://www.schaik.com/pngsuite/PngSuite.LICENSE)
#
# note: if STD_TEST_INPUT_TEST is false, then this program will try to fetch any png files from the jupyter file root directory

# %%
STD_TEST_INPUT_TEST = True
STD_TEST_INPUT_FOLDER = 'test input'
STD_TEST_INPUT_CURL = 'http://www.schaik.com/pngsuite/PngSuite-2017jul19.zip' 
STD_TEST_INPUT_SCHAIK_EXCERPT = 'libpng-schaik-excerpt.txt'
STD_TEST_INPUT_SCHAIK_EXCERPT_CURL = 'https://raw.githubusercontent.com/previoip/jupyter-png-parser/main/libpng-schaik-excerpt.txt'

# %% [markdown]
# #### > Flush to File test

# %%
TEST_FLUSH_TO_FS = True
TEST_FLUSH_FOLDER = 'export'
TEST_REPACK = True

# %% [markdown]
# ## Functions and Wrrrapers

# %%
# unpack big endian bytes into signed or unsigned integer 
# rtype: int
def _p_uint(b):
  return int.from_bytes(b, byteorder='big', signed=False)

def _p_int(b):
  return int.from_bytes(b, byteorder='big', signed=True)

# %%
# checks whether file object has reached end of file/line. I'll admit this is questionable at best.
# rtype: bool
def at_eof(fo):
    # lmao
    c = fo.read(1)
    fo.seek(-1, 1)
    if not c:
        return True
    return False

# splice bytes until first instance of null bytes is found. Returns left side of bytes and remainder bytes
# rtype: List[bytes, bytes]
def splice_null_sep(b: bytes):
    i = b.find(NULL_SEP)
    if i == -1:
        return b, b''
    return b[:i], b[i+1:]

# %%
# checks whether filepath leads to file -> png extension
# rtype: bool

re_png_ext = re_compile(r'.*(?:\.(?:p|P)(?:n|N)(?:g|G))(?:\n|\Z)')

def is_path_png(path):
    r = re_png_ext.search(path)
    if r:
        return True
    return False

# %%
# print function alternative with the ability to write to a file. Questionable and bad overall since its not async thus most overhead is presumably wasted on writing to file

suppress_print_w = False

def print_w(*argv, fp=SAVE_PRINT_FNAME, **kwargs):
    # lmfao
    if SAVE_PRINT_STDOUT:
        with open(fp, 'a') as fo:
            print(*argv, file=fo, **kwargs)
    if not suppress_print_w:
        print(*argv, **kwargs)

# %%
# get python information and program run timestamp
def get_python_stat():
    import sys
    import datetime
    r = ''
    r += 'python version : ' + sys.version + '\n'
    r += 'prog timestamp : ' + datetime.datetime.utcnow().isoformat() + '\n'
    return r

# %%
# if test with Schaik suite is True, then the excerpt is used to get the test file description

ls_png_test_fname_excerpt = {}

def load_png_test_fname_preset():
    if not STD_TEST_INPUT_SCHAIK_EXCERPT:
        return
    if not os.path.exists(STD_TEST_INPUT_SCHAIK_EXCERPT):
        return
    with open(STD_TEST_INPUT_SCHAIK_EXCERPT, 'r') as fo:
        for line in fo.readlines():
            if line.startswith('        '):
                r = [i.strip() for i in line.split('-')]
                if len(r) != 2:
                    continue
                kw, v = r
                ls_png_test_fname_excerpt[kw] = v

def parse_png_test_fname_preset(path: Path):
    if not STD_TEST_INPUT_TEST:
        return ''

    if not ls_png_test_fname_excerpt:
        load_png_test_fname_preset()

    if isinstance(path, Path):
        name = path.name
    elif isinstance(path, str):
        name = os.path.split(path)[-1]
    name = name.split('.')[0]

    r = ls_png_test_fname_excerpt.get(name)
    if not r:
        return 'not documented'
    return r

# %%
# crc implementation http://www.libpng.org/pub/png/spec/1.2/PNG-CRCAppendix.html

crc_table = [None for _ in range(256)]
is_crc_table_computed = False

def make_crc_table():
    for n in range(256):
        c = n
        for _ in range(8):
            if c & 1:
                c = 0xedb88320 ^ (c >> 1)
            else:
                c = c >> 1
        crc_table[n] = c
    is_crc_table_computed = True


def update_crc_table(crc_cksum, msg):
    c = crc_cksum

    if not is_crc_table_computed:
        make_crc_table()
    
    for b in msg:
        c = crc_table[(c ^ b) & 0xff] ^ (c >> 8)
    return c

def crc(msg: bytes):
    return update_crc_table(0xffffffff, msg) ^ 0xffffffff

def crc_to_bytes(msg: bytes):
    return struct.pack('>L', crc(msg))


# or alternatively (instead of all of these nonsense) use zlib crc instead
#
# def crc(msg=bytes):
#     from zlib import crc32
#     return crc32(msg, 0)
#
# or other sophisticated wrapper such as the ones discussed in this thread
# https://stackoverflow.com/questions/1742866/compute-crc-of-file-in-python

# %% [markdown]
# ## Main Program, Chunk Dataclass, and Parser Class

# %% [markdown]
# ### Inits

# %%
# if SAVE_PRINT is defined

# 1. delete txt file if exist
if SAVE_PRINT_PRUNE:
    if os.path.exists(SAVE_PRINT_FNAME) and os.path.isfile(SAVE_PRINT_FNAME):
        os.remove(SAVE_PRINT_FNAME)

# 2. re-instantiate file with stat on the head of the txt file
if SAVE_PRINT_STDOUT and not os.path.exists(SAVE_PRINT_FNAME):
    with open(SAVE_PRINT_FNAME, 'w') as fo:
        fo.write(get_python_stat())
        fo.write('\n\n')


# get current working directory
cwd = Path('.')


# if TEST_FLUSH is defined: create the output folder as current jupyter directory
if TEST_FLUSH_TO_FS:
  tp = cwd / TEST_FLUSH_FOLDER
  if not tp.exists():
    tp.mkdir()

# if STD_TEST_INPUT is defined
if STD_TEST_INPUT_TEST:

    # 1. change cwd to test input folder and create folder if does not exist
    cwd /= STD_TEST_INPUT_FOLDER
    if not cwd.exists(): cwd.mkdir()

    # 2. if no png files present at the folder, fetch zip file from the web
    if not list(cwd.glob('*.png')):
        import requests
        import zipfile

        r = requests.get(STD_TEST_INPUT_CURL)
        r.raise_for_status()
        buf = BytesIO(r.content)
        with zipfile.ZipFile(buf) as zf:
            zf.extractall(STD_TEST_INPUT_FOLDER)

target_files = list(cwd.glob('*.png'))
target_files[:10], target_files[-10:]
# Out:
# ([WindowsPath('test input/basi0g01.png'),
#   WindowsPath('test input/basi0g02.png'),
#   WindowsPath('test input/basi0g04.png'),
#   WindowsPath('test input/basi0g08.png'),
#   WindowsPath('test input/basi0g16.png'),
#   WindowsPath('test input/basi2c08.png'),
#   WindowsPath('test input/basi2c16.png'),
#   WindowsPath('test input/basi3p01.png'),
#   WindowsPath('test input/basi3p02.png'),
#   WindowsPath('test input/basi3p04.png')],
#  [WindowsPath('test input/xhdn0g08.png'),
#   WindowsPath('test input/xlfn0g04.png'),
#   WindowsPath('test input/xs1n0g01.png'),
#   WindowsPath('test input/xs2n0g01.png'),
#   WindowsPath('test input/xs4n0g01.png'),
#   WindowsPath('test input/xs7n0g01.png'),
#   WindowsPath('test input/z00n2c08.png'),
#   WindowsPath('test input/z03n2c08.png'),
#   WindowsPath('test input/z06n2c08.png'),
#   WindowsPath('test input/z09n2c08.png')])

# %% [markdown]
# ### Chunk Type Tag Enum

# %%
class _BaseEnum: pass

def enum_fetch_all(enum: _BaseEnum):
  _reserved = list(dir(object)) +  ['__dict__', '__module__', '__weakref__']
  return [getattr(enum, i) for i in dir(enum) if i not in _reserved]

class ENUM_PNG_CT_BYTES(_BaseEnum):

    # Critical chunk types 
    IHDR = b'IHDR'
    PLTE = b'PLTE'
    IDAT = b'IDAT'
    IEND = b'IEND'

    # Ancillary chunk types
    cHRM = b'cHRM'    # Before PLTE and IDAT
    gAMA = b'gAMA'    # Before PLTE and IDAT
    iCCP = b'iCCP'    # Before PLTE and IDAT
    sBIT = b'sBIT'    # Before PLTE and IDAT
    sRGB = b'sRGB'    # Before PLTE and IDAT
    bKGD = b'bKGD'    # After PLTE; before IDAT
    hIST = b'hIST'    # After PLTE; before IDAT
    tRNS = b'tRNS'    # After PLTE; before IDAT
    pHYs = b'pHYs'    # Before IDAT
    sPLT = b'sPLT'    # Before IDAT
    tIME = b'tIME'
    iTXt = b'iTXt'
    tEXt = b'tEXt'
    zTXt = b'zTXt'

# %%
enum_fetch_all(ENUM_PNG_CT_BYTES)
# Out:
# [b'IDAT',
#  b'IEND',
#  b'IHDR',
#  b'PLTE',
#  b'bKGD',
#  b'cHRM',
#  b'gAMA',
#  b'hIST',
#  b'iCCP',
#  b'iTXt',
#  b'pHYs',
#  b'sBIT',
#  b'sPLT',
#  b'sRGB',
#  b'tEXt',
#  b'tIME',
#  b'tRNS',
#  b'zTXt']

# %% [markdown]
# ### Dataclasses
#
# note: the following cell somewhat resembles header file but is not necessary, idk honestly it makes the whole ordeal more *profesh*

# %%
class PNGImage: pass

class I_ChunkTemplate: pass

class CT_IHDR(I_ChunkTemplate): pass
class CT_PLTE(I_ChunkTemplate): pass
class CT_PLTE(I_ChunkTemplate): pass
class CT_IDAT(I_ChunkTemplate): pass
class CT_IEND(I_ChunkTemplate): pass

class CT_cHRM(I_ChunkTemplate): pass
class CT_gAMA(I_ChunkTemplate): pass
class CT_iCCP(I_ChunkTemplate): pass
class CT_sBIT(I_ChunkTemplate): pass
class CT_sRGB(I_ChunkTemplate): pass
class CT_bKGD(I_ChunkTemplate): pass
class CT_hIST(I_ChunkTemplate): pass
class CT_tRNS(I_ChunkTemplate): pass
class CT_pHYs(I_ChunkTemplate): pass
class CT_sPLT(I_ChunkTemplate): pass
class CT_tIME(I_ChunkTemplate): pass
class CT_iTXt(I_ChunkTemplate): pass
class CT_tEXt(I_ChunkTemplate): pass
class CT_zTXt(I_ChunkTemplate): pass

class C_RGB: pass
class C_RGBA: pass

# %%
# color dataclass

@dataclass
class C_RGB:
    r: int = 0
    g: int = 0
    b: int = 0

@dataclass
class C_RGBA(C_RGB):
    a: int = 0xff


# random structs for certain chunk tags idk

@dataclass
class E_sBIT(C_RGBA): pass

@dataclass
class E_sPLT:
    color_space  : C_RGBA = C_RGBA(None, None, None, None)
    frequency    : int = None

# %% [markdown]
# ### Tags Implementations (the meat of this notebook)

# %%
# chunk type template (interface) with some custom method

@dataclass(repr=False)
class I_ChunkTemplate:
    _png_instance   : PNGImage  = None
    is_parsed       : bool      = False
    chunk_size      : int       = 0
    chunk_type      : bytes     = b''
    chunk_data      : BytesIO   = None
    chunk_crc       : bytes     = b''


    def set_pngImageInstance(self, instance):
        self._png_instance = instance

    def _parser(self):
        print_w(f'WARNING! chunk type {self.chunk_type} parser method is not yet overridden. skipping procedure.')
        return 1

    def _test(self):
        # print_w(f'chunk {self.chunk_type} test method is not yet overridden.')
        return

    def parse(self):
        if self.is_parsed:
            return 0
        if self._parser():
            return 1

        try:
            self._test()
        except AssertionError as e:
            print_w('WARNING! AssertionError:', e)
            return 1

        self.is_parsed = True

    def _pack(self):
        return f'WARNING! chunk type {self.chunk_type} pack method is not yet overridden. skipping procedure.'

    def repack(self):
        self.parse()
        temp_chunk_data = self.chunk_data
        self.chunk_data = BytesIO()
    

        if self.chunk_type == ENUM_PNG_CT_BYTES.IDAT:
            self.chunk_data = temp_chunk_data
        else:
            try:
                errmsg = self._pack()
                if errmsg:
                    raise RuntimeError(errmsg)
            except Exception as e:
                print_w('WARNING! Exception Raised:', e)
                self.chunk_data = temp_chunk_data
                return 1

        self.chunk_data.seek(0)

    def __repr__(self):
        i = [(k, v) for k, v in self.__dict__.items() if not k.startswith('_') and not k.endswith('data')]
        j = [(k, f"'{v}'") if isinstance(v, str) else (k, v) for k, v in i]
        l = [f'{k}={v}' for k, v in j]
        return '%s(%s)' % (self.__class__.__name__, ', '.join(l))

# %%
@dataclass(repr=False)
class CT_IHDR(I_ChunkTemplate):
    width               : int = None
    height              : int = None
    bit_depth           : int = None
    color_type          : int = None
    compression_method  : int = None
    filter_method       : int = None
    interlace_method    : int = None
    color_type_info     : str = ''

    def _parser(self):
        self.width              = _p_uint(self.chunk_data.read(4))
        self.height             = _p_uint(self.chunk_data.read(4))
        self.bit_depth          = _p_int(self.chunk_data.read(1))
        self.color_type         = _p_int(self.chunk_data.read(1))
        self.compression_method = _p_int(self.chunk_data.read(1))
        self.filter_method      = _p_int(self.chunk_data.read(1))
        self.interlace_method   = _p_int(self.chunk_data.read(1))
        if self.color_type & 1:
            self.color_type_info += 'palette-used;'
        if self.color_type & 2:
            self.color_type_info += 'color-used;'
        if self.color_type & 4:
            self.color_type_info += 'alpha-channel-used;'

        if self.color_type_info:
            self.color_type_info = self.color_type_info[:-1]

    def _test(self):
        assert self.width != 0, 'invalid value: width is zero'
        assert self.height != 0, 'invalid value: height is zero'

        color_type_msg = f'invalid value: color type {self.color_type} and/or bit depth {self.bit_depth} does not match specification'

        assert self.color_type in [0, 1, 2, 3, 4, 6], color_type_msg + ': valid color type values => [0, 1, 2, 3, 4, 6]'

        if self.color_type == 0:
            assert self.bit_depth in [1, 2, 4, 8, 16], color_type_msg + ': valid color type values => [1, 2, 4, 8, 16]'

        elif self.color_type == 3:
            assert self.bit_depth in [1, 2, 4, 8], color_type_msg + ': valid color type values => [1, 2, 4, 8]'

        elif self.color_type == 2 \
            or self.color_type == 4 \
            or self.color_type == 6:
            assert self.bit_depth in [8, 16], color_type_msg + ': valid color type values => [8, 16]'

    def _pack(self):
        self.chunk_data.write(
            struct.pack('>LLBBBBB', 
                self.width,
                self.height,
                self.bit_depth,
                self.color_type,
                self.compression_method,
                self.filter_method,
                self.interlace_method
            )
        )


@dataclass(repr=False)
class CT_PLTE(I_ChunkTemplate):
    entries : list = field(default_factory=list)
    
    def _parser(self):
        assert self.chunk_size % 3 == 0, 'invalid value: chunk length is not divisible by 3'
        l = self.chunk_size // 3
        for _ in range(l):
            c_rgb = C_RGB()
            c_rgb.r = _p_uint(self.chunk_data.read(1))
            c_rgb.g = _p_uint(self.chunk_data.read(1))
            c_rgb.b = _p_uint(self.chunk_data.read(1))

            self.entries.append(c_rgb)

    def _pack(self):
        for c in self.entries:
            self.chunk_data.write(
                struct.pack('>BBB', 
                    c.r,
                    c.g,
                    c.b
                )
            )

@dataclass(repr=False)
class CT_IDAT(I_ChunkTemplate):

    def _parser(self):
        pass

    def _pack(self):
        pass

@dataclass(repr=False)
class CT_IEND(I_ChunkTemplate):

    def _parser(self):
        pass

    def _pack(self):
        pass

@dataclass(repr=False)
class CT_cHRM(I_ChunkTemplate):
    white_point_x   : int = 0
    white_point_y   : int = 0
    red_x           : int = 0
    red_y           : int = 0
    green_x         : int = 0
    green_y         : int = 0
    blue_x          : int = 0
    blue_y          : int = 0

    def _parser(self):
        self.white_point_x = _p_uint(self.chunk_data.read(4))
        self.white_point_y = _p_uint(self.chunk_data.read(4))
        self.red_x         = _p_uint(self.chunk_data.read(4))
        self.red_y         = _p_uint(self.chunk_data.read(4))
        self.green_x       = _p_uint(self.chunk_data.read(4))
        self.green_y       = _p_uint(self.chunk_data.read(4))
        self.blue_x        = _p_uint(self.chunk_data.read(4))
        self.blue_y        = _p_uint(self.chunk_data.read(4))

    def _pack(self):
        self.chunk_data.write(
            struct.pack('>LLLLLLL',
                self.white_point_x,
                self.red_x,
                self.red_y,
                self.green_x,
                self.green_y,
                self.blue_x,
                self.blue_y
            )
        )

@dataclass(repr=False)
class CT_gAMA(I_ChunkTemplate):
    gamma: int = 0

    def _parser(self):
        self.gamma = _p_uint(self.chunk_data.read(4))

    def _pack(self):
        self.chunk_data.write(struct.pack('>L', self.gamma))

@dataclass(repr=False)
class CT_iCCP(I_ChunkTemplate):
    profile_name        : bytes = None
    compression_method  : bytes = None
    compression_profile : bytes = None

    def _parser(self):
        chunk = self.chunk_data.read()

        self.profile_name, compression_info = splice_null_sep(chunk)
        self.compression_method = compression_info[0:1]
        self.compression_profile = compression_info[1:]

    def _pack(self):
        self.chunk_data.write(self.profile_name)
        self.chunk_data.write(NULL_SEP)
        self.chunk_data.write(self.compression_method)
        self.chunk_data.write(self.compression_profile)

@dataclass(repr=False)
class CT_sBIT(I_ChunkTemplate):
    sbit : E_sBIT = E_sBIT(None, None, None, None)

    def _parser(self):

        ct_IHDR = self._png_instance.get_chunk(ENUM_PNG_CT_BYTES.IHDR, do_parse=True)
        color_type = ct_IHDR.color_type

        if color_type == 0:
            sbit_grey = _p_uint(self.chunk_data.read(1))
            self.sbit.r = sbit_grey
            self.sbit.g = sbit_grey
            self.sbit.b = sbit_grey
        elif color_type == 2 or color_type == 3:
            self.sbit.r = _p_uint(self.chunk_data.read(1))
            self.sbit.g = _p_uint(self.chunk_data.read(1))
            self.sbit.b = _p_uint(self.chunk_data.read(1))
        elif color_type == 4:
            sbit_grey = _p_uint(self.chunk_data.read(1))
            self.sbit.r = sbit_grey
            self.sbit.g = sbit_grey
            self.sbit.b = sbit_grey
            self.sbit.a = _p_uint(self.chunk_data.read(1))
        elif color_type == 6:
            self.sbit.r = _p_uint(self.chunk_data.read(1))
            self.sbit.g = _p_uint(self.chunk_data.read(1))
            self.sbit.b = _p_uint(self.chunk_data.read(1))
            self.sbit.a = _p_uint(self.chunk_data.read(1))

    def _pack(self):
        ct_IHDR = self._png_instance.get_chunk(ENUM_PNG_CT_BYTES.IHDR, do_parse=True)
        color_type = ct_IHDR.color_type
        if color_type == 0:
            self.chunk_data.write(struct.pack('>B', self.sbit.r))
        elif color_type == 2 or color_type == 3:
            self.chunk_data.write(
                struct.pack('>BBB', 
                    self.sbit.r,
                    self.sbit.g,
                    self.sbit.b,
                )
            )
        elif color_type == 4:
            self.chunk_data.write(
                struct.pack('>BB', 
                    self.sbit.r,
                    self.sbit.a
                )
            )
        elif color_type == 6:
            self.chunk_data.write(
                struct.pack('>BBBB', 
                    self.sbit.r,
                    self.sbit.g,
                    self.sbit.b,
                    self.sbit.a
                )
            )


@dataclass(repr=False)
class CT_sRGB(I_ChunkTemplate):
    rendering_intent : int = None
    rendering_intent_value : str = None
    
    def _parser(self):
      self.rendering_intent = _p_uint(self.chunk_data.read(1))
      self.rendering_intent_value = LS_PNG_CT_sRGB_INTENT_V[self.rendering_intent]

    def _pack(self):
        self.chunk_data.write(struct.pack('>B', self.rendering_intent))

@dataclass(repr=False)
class CT_bKGD(I_ChunkTemplate):
    background_color : C_RGB = C_RGB()
    chunk_pLTE_index : int = None

    def _parser(self):

        ct_IHDR = self._png_instance.get_chunk(ENUM_PNG_CT_BYTES.IHDR, do_parse=True)
        color_type = ct_IHDR.color_type

        if color_type == 3:
            ct_PLTE = self._png_instance.get_chunk(ENUM_PNG_CT_BYTES.PLTE, do_parse=True)
            self.chunk_pLTE_index = _p_uint(self.chunk_data.read(1))
            c = ct_PLTE.entries[self.chunk_pLTE_index]
            self.background_color.r = c.r
            self.background_color.g = c.g
            self.background_color.b = c.b
        elif color_type == 0 or color_type == 4:
            c = _p_uint(self.chunk_data.read(2))
            self.background_color.r = c
            self.background_color.g = c
            self.background_color.b = c
        elif color_type == 2 or color_type == 6:
            self.background_color.r = _p_uint(self.chunk_data.read(2))
            self.background_color.g = _p_uint(self.chunk_data.read(2))
            self.background_color.b = _p_uint(self.chunk_data.read(2))

    def _pack(self):
        ct_IHDR = self._png_instance.get_chunk(ENUM_PNG_CT_BYTES.IHDR, do_parse=True)
        color_type = ct_IHDR.color_type
        if color_type == 3:
            self.chunk_data.write(struct.pack('>B', self.chunk_pLTE_index))
        elif color_type == 0 or color_type == 4:
            self.chunk_data.write(struct.pack('>H', self.background_color.r))
        elif color_type == 2 or color_type == 6:
            self.chunk_data.write(
                struct.pack('>HHH',
                    self.background_color.r,
                    self.background_color.g,
                    self.background_color.b
                )
            )


@dataclass(repr=False)
class CT_hIST(I_ChunkTemplate):
    entries : list = field(default_factory=list)

    def _parser(self):
        l = self.chunk_size // 2
        for _ in range(l):
            self.entries.append(_p_uint(self.chunk_data.read(2)))

    def _test(self):
        ct_PLTE = self._png_instance.get_chunk(ENUM_PNG_CT_BYTES.PLTE, do_parse=True)
        assert len(ct_PLTE.entries) == len(self.entries), 'invalid value: chunk hIST does not have equal length with PLTE'

    def _pack(self):
        for i in self.entries:
            self.chunk_data.write(struct.pack('>H', i))

@dataclass(repr=False)
class CT_tRNS(I_ChunkTemplate):
    alpha_channel : list = field(default_factory=list)

    def _parser(self):
        ct_IHDR = self._png_instance.get_chunk(ENUM_PNG_CT_BYTES.IHDR, do_parse=True)
        bit_depth = ct_IHDR.bit_depth
        color_type = ct_IHDR.color_type

        if color_type == 0:
            self.alpha_channel.append(
                _p_uint(self.chunk_data.read(2))
            )

        if color_type == 2:
            c_rgb = C_RGB()
            c_rgb.r = _p_uint(self.chunk_data.read(2))
            c_rgb.g = _p_uint(self.chunk_data.read(2))
            c_rgb.b = _p_uint(self.chunk_data.read(2))
            self.alpha_channel.append(
                c_rgb
            )

        if color_type == 3:
            for _ in range(self.chunk_size):
                self.alpha_channel.append(
                    _p_uint(self.chunk_data.read(1))
                )

    def _test(self):
        ct_IHDR = self._png_instance.get_chunk(ENUM_PNG_CT_BYTES.IHDR)
        color_type = ct_IHDR.color_type
        assert color_type not in [4, 6], f'invalid value: {self.chunk_type} prohibited for color types 4 and 6'

    def _pack(self):
        ct_IHDR = self._png_instance.get_chunk(ENUM_PNG_CT_BYTES.IHDR, do_parse=True)
        bit_depth = ct_IHDR.bit_depth
        color_type = ct_IHDR.color_type
        if color_type == 0 or color_type == 3:
            for i in self.alpha_channel:
                self.chunk_data.write(struct.pack('>B', i))
        elif color_type == 2:
            for c in self.alpha_channel:
                self.chunk_data.write(
                    struct.pack('>BBB', 
                        c.r,
                        c.g,
                        c.b
                    )
                )


@dataclass(repr=False)
class CT_pHYs(I_ChunkTemplate):
    pixel_per_unit_x : int = None
    pixel_per_unit_y : int = None
    unit_specifier   : int = None

    def _parser(self):
        self.pixel_per_unit_x = _p_uint(self.chunk_data.read(4))
        self.pixel_per_unit_y = _p_uint(self.chunk_data.read(4))
        self.unit_specifier = _p_uint(self.chunk_data.read(1))

    def _test(self):
        assert self.unit_specifier in [0, 1]

    def _pack(self):
        self.chunk_data.write(
            struct.pack('>LLB',
                self.pixel_per_unit_x,
                self.pixel_per_unit_y,
                self.unit_specifier
            )
        )

@dataclass(repr=False)
class CT_sPLT(I_ChunkTemplate):
    palette_name : bytes = None
    sample_depth : int = None
    entries      : list = field(default_factory=list)

    def _parser(self):
        chunk = self.chunk_data.read()
        self.palette_name, chunk = splice_null_sep(chunk)
        self.sample_depth, chunk = _p_uint(chunk[:1]), chunk[1:]
        n = 0
        l = 0
        if self.sample_depth == 8:
            n = 1
            l = len(chunk) // 6
        elif self.sample_depth == 16:
            n = 2
            l = len(chunk) // 10

        for _ in range(l):
            e_sPLT = E_sPLT()
            e_sPLT.color_space.r, chunk = _p_uint(chunk[:n]), chunk[n:]
            e_sPLT.color_space.g, chunk = _p_uint(chunk[:n]), chunk[n:]
            e_sPLT.color_space.b, chunk = _p_uint(chunk[:n]), chunk[n:]
            e_sPLT.color_space.a, chunk = _p_uint(chunk[:n]), chunk[n:]
            e_sPLT.frequency, chunk = _p_uint(chunk[:2]), chunk[2:]
            self.entries.append(e_sPLT)

            if not chunk:
                break

    def _pack(self):
        self.chunk_data.write(palette_name)
        self.chunk_data.write(struct.pack('>B', sample_depth))

        n = 0
        l = 0
        if self.sample_depth == 8:
            n = 1
        elif self.sample_depth == 16:
            n = 2

        for e in self.entries:
            fmt = ''
            if n == 1:
                fmt = 'B'
            elif n == 2:
                fmt = 'H'
            else:
                raise ValueError('huh')

            self.chunk_data.write(
                struct.pack(f'>{fmt*4}H', 
                    e.color_space.r,
                    e.color_space.g,
                    e.color_space.b,
                    e.color_space.a,
                    e.frequency
                )
            )



@dataclass(repr=False)
class CT_tIME(I_ChunkTemplate):
    year    : int = None
    month   : int = None
    day     : int = None
    hour    : int = None
    minute  : int = None
    second  : int = None

    def _parser(self):
        self.year   = _p_uint(self.chunk_data.read(2))
        self.month  = _p_uint(self.chunk_data.read(1))
        self.day    = _p_uint(self.chunk_data.read(1))
        self.hour   = _p_uint(self.chunk_data.read(1))
        self.minute = _p_uint(self.chunk_data.read(1))
        self.second = _p_uint(self.chunk_data.read(1))

    def _test(self):
        assert self.month  in range(1, 13)
        assert self.day    in range(1, 32)
        assert self.hour   in range(24)
        assert self.minute in range(60)
        assert self.second in range(61)

    def _pack(self):
        self.chunk_data.write(
            struct.pack('>HBBBB', 
                self.year,
                self.month,
                self.day,
                self.hour,
                self.minute,
                self.second
            )
        )

@dataclass(repr=False)
class CT_iTXt(I_ChunkTemplate):
    keyword             : bytes = None
    compression_flag    : int = None
    compression_method  : int = None
    language_tag        : bytes = None
    translated_keyword  : bytes = None
    text                : bytes = None

    def _parser(self):
        chunk = self.chunk_data.read()

        self.keyword, chunk = splice_null_sep(chunk)
        self.compression_flag, chunk = chunk[:1], chunk[1:]
        self.compression_method, chunk = chunk[:1], chunk[1:]
        self.language_tag, chunk = splice_null_sep(chunk)
        self.translated_keyword, chunk = splice_null_sep(chunk)
        self.text, chunk = splice_null_sep(chunk)

    def _pack(self):
        self.chunk_data.writelines(
            [
                self.keyword,
                NULL_SEP,
                self.compression_flag,
                self.compression_method,
                self.language_tag,
                NULL_SEP,
                self.translated_keyword,
                NULL_SEP,
                self.text
            ]
        )

@dataclass(repr=False)
class CT_tEXt(I_ChunkTemplate):
    keyword : bytes = ''
    text    : bytes = ''
    
    def _parser(self):
        chunk = self.chunk_data.read()
        self.keyword, self.text = splice_null_sep(chunk)

    def _pack(self):
        self.chunk_data.writelines(
            [
                self.keyword,
                NULL_SEP,
                self.text
            ]
        )


@dataclass(repr=False)
class CT_zTXt(I_ChunkTemplate):
    keyword             : bytes = None
    compression_method  : int = None
    compressed_text     : bytes = None

    def _parser(self):
        chunk = self.chunk_data.read()
        self.keyword, chunk = splice_null_sep(chunk)
        self.compression_method, self.compressed_text = chunk[:1], chunk[1:]

    def _pack(self):
        self.chunk_data.writelines(
            [
                self.keyword,
                NULL_SEP,
                struct.pack('>B', self.compression_method),
                self.compressed_text
            ]
        )

# %% [markdown]
# ### PNG Class

# %%
class PNGImage:
    verbose : bool = False

    def __init__(self):
        self.signature = PNG_SIGNATURE
        self._chunks   = list()
        self._fname    = ''
        self._ext      = '.png'

    def set_filename(self, filename: str):
        self._fname = filename.split('.')[0]

    def get_filename(self):
        return self._fname + self._ext

    def set_signature(self, signature: bytes):
        self.signature = signature

    def check_signature(self, signature: bytes):
        return signature == PNG_SIGNATURE

    def append_chunk(self, ct: I_ChunkTemplate):
        ct.set_pngImageInstance(self)
        self._chunks.append(ct)

    def iter_chunks(self, chunk_type_enum = None):
        for i in self._chunks:
            if chunk_type_enum:
                if i.chunk_type != chunk_type_enum:
                    continue
            yield i

    def get_chunks(self, chunk_type_enum = None, do_parse = False):
        if chunk_type_enum:
            r = list(filter(lambda x: x.chunk_type == chunk_type_enum, self._chunks))
        else:
            r = self._chunks

        if do_parse:
            _ = [i.parse() for i in r]

        return r

    def get_chunk(self, chunk_type_enum = None, do_parse = False):
        r = self.get_chunks(chunk_type_enum)[0]
        if do_parse:
            r.parse()
        return r

    def parse_all(self):
        for c in self.iter_chunks():
            if self.verbose: print_w(f'parsing {c.chunk_type}; {c.chunk_size} bytes')
            errno = c.parse()
            if errno:
                # return
                pass

    def repack_all(self):
        for c in self.iter_chunks():
            if self.verbose: print_w(f'packing {c.chunk_type}; {c.chunk_size} bytes')
            errno = c.repack()
            if errno:
                # return
                pass

    def flush(self, fo):
        fo.write(self.signature)
        for c in self.iter_chunks():
            chunk_data = b''
            if c.chunk_data:
                c.chunk_data.seek(0)
                chunk_data = c.chunk_data.read()
            fo.write(struct.pack('>I', c.chunk_size))
            fo.write(c.chunk_type)
            fo.write(chunk_data)
            fo.write(crc_to_bytes(c.chunk_type + chunk_data))

    def sizeof(self):
        return sum(map(lambda x: x.chunk_size, self.iter_chunks()))

    def __repr__(self):

        # default:
        #
        # return '<%s.%s object at %s>' % (
        #     self.__class__.__module__,
        #     self.__class__.__name__,
        #     hex(id(self))
        # )

        return '<%s %s>' % (
            self.__class__.__name__,
            hex(id(self))
        )

PNGImage.verbose = VERBOSE

# %% [markdown]
# ### Wrap em up

# %%
chunk_struct_constructor_dict = {
    ENUM_PNG_CT_BYTES.IHDR: CT_IHDR,
    ENUM_PNG_CT_BYTES.IDAT: CT_IDAT,
    ENUM_PNG_CT_BYTES.IEND: CT_IEND,
    ENUM_PNG_CT_BYTES.PLTE: CT_PLTE,

    ENUM_PNG_CT_BYTES.cHRM: CT_cHRM,
    ENUM_PNG_CT_BYTES.gAMA: CT_gAMA,
    ENUM_PNG_CT_BYTES.iCCP: CT_iCCP,
    ENUM_PNG_CT_BYTES.sBIT: CT_sBIT,
    ENUM_PNG_CT_BYTES.sRGB: CT_sRGB,
    ENUM_PNG_CT_BYTES.bKGD: CT_bKGD,
    ENUM_PNG_CT_BYTES.hIST: CT_hIST,
    ENUM_PNG_CT_BYTES.tRNS: CT_tRNS,
    ENUM_PNG_CT_BYTES.pHYs: CT_pHYs,
    ENUM_PNG_CT_BYTES.sPLT: CT_sPLT,
    ENUM_PNG_CT_BYTES.tIME: CT_tIME,
    ENUM_PNG_CT_BYTES.iTXt: CT_iTXt,
    ENUM_PNG_CT_BYTES.tEXt: CT_tEXt,
    ENUM_PNG_CT_BYTES.zTXt: CT_zTXt,
}

# %%
def parse_png_file(path: Path, do_parse: bool = True) -> PNGImage:

    filename = ''
    if isinstance(path, Path):
        filename = path.name
    elif isinstance(path, str):
        filename = os.path.split(path)[-1]

    if not is_path_png(filename):
        print_w(f'file {filename} does not have correct png extension')
        return

    png = PNGImage()
    png.set_filename(filename)

    with open(path, 'rb') as fo:
        png_signature = fo.read(8)

        # for the sake of continuity, this and the rest of basic value checks does not raise any error
        if not png.check_signature(png_signature):
            print_w(f'WARNING! file does not contain or has correct PNG signature: {png_signature}') 
            png.set_signature(png_signature) 

        while not at_eof(fo):
            chunk_size = _p_uint(fo.read(4))
            chunk_type = fo.read(4)
            chunk_data = fo.read(chunk_size)
            chunk_crc  = fo.read(4)

            if chunk_crc != crc_to_bytes(chunk_type + chunk_data):
                print_w('WARNING! file is corrupted: crc hash does not match')

            if chunk_type not in enum_fetch_all(ENUM_PNG_CT_BYTES):
                print_w(f'WARNING! chunk type {chunk_type} is not present in ENUM_PNG_CT_BYTES')
                continue

            elif chunk_type not in chunk_struct_constructor_dict:
                print_w(f'WARNING! chunk type {chunk_type} parser is not yet implemented')
                continue

            t = chunk_struct_constructor_dict.get(chunk_type)()
            png.append_chunk(t)

            t.chunk_size = chunk_size
            t.chunk_data = BytesIO(chunk_data) if chunk_size else None
            t.chunk_type = chunk_type
            t.chunk_crc = chunk_crc

        if do_parse:
            png.parse_all()

    return png

# %% [markdown]
# ### main()

# %%
# %%capture parse_pngs --no-display

total_time_elapsed = 0
total_size_parsed = 0
total_n_files = len(target_files)
for n_f, target_file_path in enumerate(target_files):
    n_f += 1
    suppress_print_w = True
    if VERBOSE: print_w('-------------------------------------------------')
    suppress_print_w = False
    if VERBOSE: print_w(f'file {n_f:03}/{total_n_files:03}')
    if VERBOSE: print_w('target file      :', f'"{target_file_path}"')
    if STD_TEST_INPUT_TEST and VERBOSE:
        print_w('test description :', parse_png_test_fname_preset(target_file_path))
    suppress_print_w = True
    if VERBOSE: print_w('-------------------------------------------------')

    start = time.time()
    png = parse_png_file(target_file_path)
    elapsed = time.time() - start

    total_time_elapsed += elapsed
    total_size_parsed += png.sizeof()

    if VERBOSE: print_w(f'parsed chunks:', )
    if png:
        for n, c in enumerate(png.iter_chunks()):
            if VERBOSE: print_w(f'  [{n:03}] -', c)
    
        if TEST_FLUSH_TO_FS:
            if TEST_REPACK:
                if VERBOSE: print_w('repacking parsed result')
                png.repack_all()
            with open(Path(TEST_FLUSH_FOLDER) / png.get_filename(), 'wb') as fo:
                png.flush(fo)

    if VERBOSE: print_w('-------------------------------------------------')
    if VERBOSE: print_w('parser status    :', 'succeed' if all(map(lambda x: x.is_parsed, png.iter_chunks())) else 'failed')
    suppress_print_w = False
    if VERBOSE: print_w('elapsed time     :', f'{elapsed} seconds')
    suppress_print_w = True
    if VERBOSE: print_w('-------------------------------------------------')
    if VERBOSE: print_w()
    suppress_print_w = False
    if VERBOSE: print_w()

if VERBOSE: print_w('=================================================')
if VERBOSE: print_w('some stats:')
if VERBOSE: print_w('  - total file parsed   :', f'{len(target_files)}')
if VERBOSE: print_w('  - inferred total size :', f'{total_size_parsed} bytes')
if VERBOSE: print_w('  - total elapsed time  :', f'{total_time_elapsed} seconds')
# Out:
# file 001/176
# target file      : "test input\basi0g01.png"
# test description : black & white
# elapsed time     : 0.0015132427215576172 seconds
#
# file 002/176
# target file      : "test input\basi0g02.png"
# test description : 2 bit (4 level) grayscale
# elapsed time     : 0.0019981861114501953 seconds
#
# file 003/176
# target file      : "test input\basi0g04.png"
# test description : 4 bit (16 level) grayscale
# elapsed time     : 0.0016047954559326172 seconds
#
# file 004/176
# target file      : "test input\basi0g08.png"
# test description : 8 bit (256 level) grayscale
# elapsed time     : 0.001996755599975586 seconds
#
# file 005/176
# target file      : "test input\basi0g16.png"
# test description : 16 bit (64k level) grayscale
# elapsed time     : 0.002540111541748047 seconds
#
# file 006/176
# target file      : "test input\basi2c08.png"
# test description : 3x8 bits rgb color
# elapsed time     : 0.0009984970092773438 seconds
#
# file 007/176
# target file      : "test input\basi2c16.png"
# test description : 3x16 bits rgb color
# elapsed time     : 0.0020003318786621094 seconds
#
# file 008/176
# target file      : "test input\basi3p01.png"
# test description : 1 bit (2 color) paletted
# elapsed time     : 0.002999544143676758 seconds
#
# file 009/176
# target file      : "test input\basi3p02.png"
# test description : 2 bit (4 color) paletted
# elapsed time     : 0.00262451171875 seconds
#
# file 010/176
# target file      : "test input\basi3p04.png"
# test description : 4 bit (16 color) paletted
# elapsed time     : 0.0030014514923095703 seconds
#
# file 011/176
# target file      : "test input\basi3p08.png"
# test description : 8 bit (256 color) paletted
# elapsed time     : 0.002359628677368164 seconds
#
# file 012/176
# target file      : "test input\basi4a08.png"
# test description : not documented
# elapsed time     : 0.0020079612731933594 seconds
#
# file 013/176
# target file      : "test input\basi4a16.png"
# test description : not documented
# elapsed time     : 0.0027260780334472656 seconds
#
# file 014/176
# target file      : "test input\basi6a08.png"
# test description : not documented
# elapsed time     : 0.0025191307067871094 seconds
#
# file 015/176
# target file      : "test input\basi6a16.png"
# test description : not documented
# elapsed time     : 0.0028417110443115234 seconds
#
# file 016/176
# target file      : "test input\basn0g01.png"
# test description : black & white
# elapsed time     : 0.0020101070404052734 seconds
#
# file 017/176
# target file      : "test input\basn0g02.png"
# test description : 2 bit (4 level) grayscale
# elapsed time     : 0.0020034313201904297 seconds
#
# file 018/176
# target file      : "test input\basn0g04.png"
# test description : 4 bit (16 level) grayscale
# elapsed time     : 0.0026204586029052734 seconds
#
# file 019/176
# target file      : "test input\basn0g08.png"
# test description : 8 bit (256 level) grayscale
# elapsed time     : 0.002515554428100586 seconds
#
# file 020/176
# target file      : "test input\basn0g16.png"
# test description : 16 bit (64k level) grayscale
# elapsed time     : 0.0020029544830322266 seconds
#
# file 021/176
# target file      : "test input\basn2c08.png"
# test description : 3x8 bits rgb color
# elapsed time     : 0.00200653076171875 seconds
#
# file 022/176
# target file      : "test input\basn2c16.png"
# test description : 3x16 bits rgb color
# elapsed time     : 0.002006053924560547 seconds
#
# file 023/176
# target file      : "test input\basn3p01.png"
# test description : 1 bit (2 color) paletted
# elapsed time     : 0.002234220504760742 seconds
#
# file 024/176
# target file      : "test input\basn3p02.png"
# test description : 2 bit (4 color) paletted
# elapsed time     : 0.0035202503204345703 seconds
#
# file 025/176
# target file      : "test input\basn3p04.png"
# test description : 4 bit (16 color) paletted
# elapsed time     : 0.0035207271575927734 seconds
#
# file 026/176
# target file      : "test input\basn3p08.png"
# test description : 8 bit (256 color) paletted
# elapsed time     : 0.004033327102661133 seconds
#
# file 027/176
# target file      : "test input\basn4a08.png"
# test description : not documented
# elapsed time     : 0.002018451690673828 seconds
#
# file 028/176
# target file      : "test input\basn4a16.png"
# test description : not documented
# elapsed time     : 0.002518892288208008 seconds
#
# file 029/176
# target file      : "test input\basn6a08.png"
# test description : not documented
# elapsed time     : 0.0035812854766845703 seconds
#
# file 030/176
# target file      : "test input\basn6a16.png"
# test description : not documented
# elapsed time     : 0.0020055770874023438 seconds
#
# file 031/176
# target file      : "test input\bgai4a08.png"
# test description : 8 bit grayscale, alpha, no background chunk
# elapsed time     : 0.0020761489868164062 seconds
#
# file 032/176
# target file      : "test input\bgai4a16.png"
# test description : 16 bit grayscale, alpha, no background chunk
# elapsed time     : 0.002607107162475586 seconds
#
# file 033/176
# target file      : "test input\bgan6a08.png"
# test description : 3x8 bits rgb color, alpha, no background chunk
# elapsed time     : 0.0014371871948242188 seconds
#
# file 034/176
# target file      : "test input\bgan6a16.png"
# test description : 3x16 bits rgb color, alpha, no background chunk
# elapsed time     : 0.0035886764526367188 seconds
#
# file 035/176
# target file      : "test input\bgbn4a08.png"
# test description : 8 bit grayscale, alpha, black background chunk
# elapsed time     : 0.002002239227294922 seconds
#
# file 036/176
# target file      : "test input\bggn4a16.png"
# test description : 16 bit grayscale, alpha, gray background chunk
# elapsed time     : 0.002373218536376953 seconds
#
# file 037/176
# target file      : "test input\bgwn6a08.png"
# test description : 3x8 bits rgb color, alpha, white background chunk
# elapsed time     : 0.0034253597259521484 seconds
#
# file 038/176
# target file      : "test input\bgyn6a16.png"
# test description : 3x16 bits rgb color, alpha, yellow background chunk
# elapsed time     : 0.0029990673065185547 seconds
#
# file 039/176
# target file      : "test input\ccwn2c08.png"
# test description : chroma chunk w:0.3127,0.3290 r:0.64,0.33 g:0.30,0.60 b:0.15,0.06
# elapsed time     : 0.00200653076171875 seconds
#
# file 040/176
# target file      : "test input\ccwn3p08.png"
# test description : chroma chunk w:0.3127,0.3290 r:0.64,0.33 g:0.30,0.60 b:0.15,0.06
# elapsed time     : 0.025149822235107422 seconds
#
# file 041/176
# target file      : "test input\cdfn2c08.png"
# test description : physical pixel dimensions, 8x32 flat pixels
# elapsed time     : 0.003149747848510742 seconds
#
# file 042/176
# target file      : "test input\cdhn2c08.png"
# test description : physical pixel dimensions, 32x8 high pixels
# elapsed time     : 0.0030601024627685547 seconds
#
# file 043/176
# target file      : "test input\cdsn2c08.png"
# test description : physical pixel dimensions, 8x8 square pixels
# elapsed time     : 0.0024993419647216797 seconds
#
# file 044/176
# target file      : "test input\cdun2c08.png"
# test description : physical pixel dimensions, 1000 pixels per 1 meter
# elapsed time     : 0.003905773162841797 seconds
#
# file 045/176
# target file      : "test input\ch1n3p04.png"
# test description : histogram 15 colors
# elapsed time     : 0.004019498825073242 seconds
#
# file 046/176
# target file      : "test input\ch2n3p08.png"
# test description : histogram 256 colors
# elapsed time     : 0.004514932632446289 seconds
#
# file 047/176
# target file      : "test input\cm0n0g04.png"
# test description : not documented
# elapsed time     : 0.0025136470794677734 seconds
#
# file 048/176
# target file      : "test input\cm7n0g04.png"
# test description : not documented
# elapsed time     : 0.0035140514373779297 seconds
#
# file 049/176
# target file      : "test input\cm9n0g04.png"
# test description : not documented
# elapsed time     : 0.0025005340576171875 seconds
#
# file 050/176
# target file      : "test input\cs3n2c16.png"
# test description : color, 13 significant bits
# elapsed time     : 0.002012014389038086 seconds
#
# file 051/176
# target file      : "test input\cs3n3p08.png"
# test description : paletted, 3 significant bits
# elapsed time     : 0.003024578094482422 seconds
#
# file 052/176
# target file      : "test input\cs5n2c08.png"
# test description : color, 5 significant bits
# elapsed time     : 0.002008199691772461 seconds
#
# file 053/176
# target file      : "test input\cs5n3p08.png"
# test description : paletted, 5 significant bits
# elapsed time     : 0.003902435302734375 seconds
#
# file 054/176
# target file      : "test input\cs8n2c08.png"
# test description : color, 8 significant bits (reference)
# elapsed time     : 0.0019991397857666016 seconds
#
# file 055/176
# target file      : "test input\cs8n3p08.png"
# test description : paletted, 8 significant bits (reference)
# elapsed time     : 0.0029969215393066406 seconds
#
# file 056/176
# target file      : "test input\ct0n0g04.png"
# test description : no textual data
# elapsed time     : 0.002000093460083008 seconds
#
# file 057/176
# target file      : "test input\ct1n0g04.png"
# test description : with textual data
# elapsed time     : 0.006142377853393555 seconds
#
# file 058/176
# target file      : "test input\cten0g04.png"
# test description : not documented
# elapsed time     : 0.007099151611328125 seconds
#
# file 059/176
# target file      : "test input\ctfn0g04.png"
# test description : not documented
# elapsed time     : 0.007413625717163086 seconds
#
# file 060/176
# target file      : "test input\ctgn0g04.png"
# test description : not documented
# elapsed time     : 0.006519317626953125 seconds
#
# file 061/176
# target file      : "test input\cthn0g04.png"
# test description : not documented
# elapsed time     : 0.0048182010650634766 seconds
#
# file 062/176
# target file      : "test input\ctjn0g04.png"
# test description : not documented
# elapsed time     : 0.005529642105102539 seconds
#
# file 063/176
# target file      : "test input\ctzn0g04.png"
# test description : with compressed textual data
# elapsed time     : 0.005517244338989258 seconds
#
# file 064/176
# target file      : "test input\exif2c08.png"
# test description : not documented
# elapsed time     : 0.002942800521850586 seconds
#
# file 065/176
# target file      : "test input\f00n0g08.png"
# test description : not documented
# elapsed time     : 0.0034618377685546875 seconds
#
# file 066/176
# target file      : "test input\f00n2c08.png"
# test description : not documented
# elapsed time     : 0.0020122528076171875 seconds
#
# file 067/176
# target file      : "test input\f01n0g08.png"
# test description : not documented
# elapsed time     : 0.0020477771759033203 seconds
#
# file 068/176
# target file      : "test input\f01n2c08.png"
# test description : not documented
# elapsed time     : 0.002046346664428711 seconds
#
# file 069/176
# target file      : "test input\f02n0g08.png"
# test description : not documented
# elapsed time     : 0.0020084381103515625 seconds
#
# file 070/176
# target file      : "test input\f02n2c08.png"
# test description : not documented
# elapsed time     : 0.002407073974609375 seconds
#
# file 071/176
# target file      : "test input\f03n0g08.png"
# test description : not documented
# elapsed time     : 0.0019981861114501953 seconds
#
# file 072/176
# target file      : "test input\f03n2c08.png"
# test description : not documented
# elapsed time     : 0.0012292861938476562 seconds
#
# file 073/176
# target file      : "test input\f04n0g08.png"
# test description : not documented
# elapsed time     : 0.0021266937255859375 seconds
#
# file 074/176
# target file      : "test input\f04n2c08.png"
# test description : not documented
# elapsed time     : 0.002409219741821289 seconds
#
# file 075/176
# target file      : "test input\f99n0g04.png"
# test description : not documented
# elapsed time     : 0.0020008087158203125 seconds
#
# file 076/176
# target file      : "test input\g03n0g16.png"
# test description : not documented
# elapsed time     : 0.002293109893798828 seconds
#
# file 077/176
# target file      : "test input\g03n2c08.png"
# test description : not documented
# elapsed time     : 0.0025894641876220703 seconds
#
# file 078/176
# target file      : "test input\g03n3p04.png"
# test description : not documented
# elapsed time     : 0.0013098716735839844 seconds
#
# file 079/176
# target file      : "test input\g04n0g16.png"
# test description : not documented
# elapsed time     : 0.002063751220703125 seconds
#
# file 080/176
# target file      : "test input\g04n2c08.png"
# test description : not documented
# elapsed time     : 0.0024662017822265625 seconds
#
# file 081/176
# target file      : "test input\g04n3p04.png"
# test description : not documented
# elapsed time     : 0.0020177364349365234 seconds
#
# file 082/176
# target file      : "test input\g05n0g16.png"
# test description : not documented
# elapsed time     : 0.003010988235473633 seconds
#
# file 083/176
# target file      : "test input\g05n2c08.png"
# test description : not documented
# elapsed time     : 0.002824544906616211 seconds
#
# file 084/176
# target file      : "test input\g05n3p04.png"
# test description : not documented
# elapsed time     : 0.0030121803283691406 seconds
#
# file 085/176
# target file      : "test input\g07n0g16.png"
# test description : not documented
# elapsed time     : 0.0028488636016845703 seconds
#
# file 086/176
# target file      : "test input\g07n2c08.png"
# test description : not documented
# elapsed time     : 0.0015993118286132812 seconds
#
# file 087/176
# target file      : "test input\g07n3p04.png"
# test description : not documented
# elapsed time     : 0.0022721290588378906 seconds
#
# file 088/176
# target file      : "test input\g10n0g16.png"
# test description : not documented
# elapsed time     : 0.0021622180938720703 seconds
#
# file 089/176
# target file      : "test input\g10n2c08.png"
# test description : not documented
# elapsed time     : 0.002458333969116211 seconds
#
# file 090/176
# target file      : "test input\g10n3p04.png"
# test description : not documented
# elapsed time     : 0.0025131702423095703 seconds
#
# file 091/176
# target file      : "test input\g25n0g16.png"
# test description : not documented
# elapsed time     : 0.0014576911926269531 seconds
#
# file 092/176
# target file      : "test input\g25n2c08.png"
# test description : not documented
# elapsed time     : 0.002026796340942383 seconds
#
# file 093/176
# target file      : "test input\g25n3p04.png"
# test description : not documented
# elapsed time     : 0.0020041465759277344 seconds
#
# file 094/176
# target file      : "test input\oi1n0g16.png"
# test description : not documented
# elapsed time     : 0.002007722854614258 seconds
#
# file 095/176
# target file      : "test input\oi1n2c16.png"
# test description : not documented
# elapsed time     : 0.0016849040985107422 seconds
#
# file 096/176
# target file      : "test input\oi2n0g16.png"
# test description : not documented
# elapsed time     : 0.0020024776458740234 seconds
#
# file 097/176
# target file      : "test input\oi2n2c16.png"
# test description : not documented
# elapsed time     : 0.0017952919006347656 seconds
#
# file 098/176
# target file      : "test input\oi4n0g16.png"
# test description : not documented
# elapsed time     : 0.0030066967010498047 seconds
#
# file 099/176
# target file      : "test input\oi4n2c16.png"
# test description : not documented
# elapsed time     : 0.0030090808868408203 seconds
#
# file 100/176
# target file      : "test input\oi9n0g16.png"
# test description : not documented
# elapsed time     : 0.04190707206726074 seconds
#
# file 101/176
# target file      : "test input\oi9n2c16.png"
# test description : not documented
# elapsed time     : 0.10107874870300293 seconds
#
# file 102/176
# target file      : "test input\PngSuite.png"
# test description : not documented
# elapsed time     : 0.001997232437133789 seconds
#
# file 103/176
# target file      : "test input\pp0n2c16.png"
# test description : not documented
# elapsed time     : 0.003746509552001953 seconds
#
# file 104/176
# target file      : "test input\pp0n6a08.png"
# test description : not documented
# elapsed time     : 0.003125905990600586 seconds
#
# file 105/176
# target file      : "test input\ps1n0g08.png"
# test description : not documented
# elapsed time     : 0.004099369049072266 seconds
#
# file 106/176
# target file      : "test input\ps1n2c16.png"
# test description : not documented
# elapsed time     : 0.002860546112060547 seconds
#
# file 107/176
# target file      : "test input\ps2n0g08.png"
# test description : not documented
# elapsed time     : 0.0037462711334228516 seconds
#
# file 108/176
# target file      : "test input\ps2n2c16.png"
# test description : not documented
# elapsed time     : 0.0031626224517822266 seconds
#
# file 109/176
# target file      : "test input\s01i3p01.png"
# test description : 1x1 paletted file, interlaced
# elapsed time     : 0.0037147998809814453 seconds
#
# file 110/176
# target file      : "test input\s01n3p01.png"
# test description : 1x1 paletted file, no interlacing
# elapsed time     : 0.0029985904693603516 seconds
#
# file 111/176
# target file      : "test input\s02i3p01.png"
# test description : 2x2 paletted file, interlaced
# elapsed time     : 0.0025086402893066406 seconds
#
# file 112/176
# target file      : "test input\s02n3p01.png"
# test description : 2x2 paletted file, no interlacing
# elapsed time     : 0.002998828887939453 seconds
#
# file 113/176
# target file      : "test input\s03i3p01.png"
# test description : 3x3 paletted file, interlaced
# elapsed time     : 0.003309011459350586 seconds
#
# file 114/176
# target file      : "test input\s03n3p01.png"
# test description : 3x3 paletted file, no interlacing
# elapsed time     : 0.0039746761322021484 seconds
#
# file 115/176
# target file      : "test input\s04i3p01.png"
# test description : 4x4 paletted file, interlaced
# elapsed time     : 0.0029904842376708984 seconds
#
# file 116/176
# target file      : "test input\s04n3p01.png"
# test description : 4x4 paletted file, no interlacing
# elapsed time     : 0.0032510757446289062 seconds
#
# file 117/176
# target file      : "test input\s05i3p02.png"
# test description : 5x5 paletted file, interlaced
# elapsed time     : 0.0030221939086914062 seconds
#
# file 118/176
# target file      : "test input\s05n3p02.png"
# test description : 5x5 paletted file, no interlacing
# elapsed time     : 0.0032694339752197266 seconds
#
# file 119/176
# target file      : "test input\s06i3p02.png"
# test description : 6x6 paletted file, interlaced
# elapsed time     : 0.0030028820037841797 seconds
#
# file 120/176
# target file      : "test input\s06n3p02.png"
# test description : 6x6 paletted file, no interlacing
# elapsed time     : 0.0029976367950439453 seconds
#
# file 121/176
# target file      : "test input\s07i3p02.png"
# test description : 7x7 paletted file, interlaced
# elapsed time     : 0.004001617431640625 seconds
#
# file 122/176
# target file      : "test input\s07n3p02.png"
# test description : 7x7 paletted file, no interlacing
# elapsed time     : 0.003299713134765625 seconds
#
# file 123/176
# target file      : "test input\s08i3p02.png"
# test description : 8x8 paletted file, interlaced
# elapsed time     : 0.002997875213623047 seconds
#
# file 124/176
# target file      : "test input\s08n3p02.png"
# test description : 8x8 paletted file, no interlacing
# elapsed time     : 0.002964019775390625 seconds
#
# file 125/176
# target file      : "test input\s09i3p02.png"
# test description : 9x9 paletted file, interlaced
# elapsed time     : 0.0029997825622558594 seconds
#
# file 126/176
# target file      : "test input\s09n3p02.png"
# test description : 9x9 paletted file, no interlacing
# elapsed time     : 0.0025169849395751953 seconds
#
# file 127/176
# target file      : "test input\s32i3p04.png"
# test description : 32x32 paletted file, interlaced
# elapsed time     : 0.0034177303314208984 seconds
#
# file 128/176
# target file      : "test input\s32n3p04.png"
# test description : 32x32 paletted file, no interlacing
# elapsed time     : 0.002000093460083008 seconds
#
# file 129/176
# target file      : "test input\s33i3p04.png"
# test description : 33x33 paletted file, interlaced
# elapsed time     : 0.0030035972595214844 seconds
#
# file 130/176
# target file      : "test input\s33n3p04.png"
# test description : 33x33 paletted file, no interlacing
# elapsed time     : 0.006001710891723633 seconds
#
# file 131/176
# target file      : "test input\s34i3p04.png"
# test description : 34x34 paletted file, interlaced
# elapsed time     : 0.003000974655151367 seconds
#
# file 132/176
# target file      : "test input\s34n3p04.png"
# test description : 34x34 paletted file, no interlacing
# elapsed time     : 0.0020096302032470703 seconds
#
# file 133/176
# target file      : "test input\s35i3p04.png"
# test description : 35x35 paletted file, interlaced
# elapsed time     : 0.0019986629486083984 seconds
#
# file 134/176
# target file      : "test input\s35n3p04.png"
# test description : 35x35 paletted file, no interlacing
# elapsed time     : 0.0030035972595214844 seconds
#
# file 135/176
# target file      : "test input\s36i3p04.png"
# test description : 36x36 paletted file, interlaced
# elapsed time     : 0.003002166748046875 seconds
#
# file 136/176
# target file      : "test input\s36n3p04.png"
# test description : 36x36 paletted file, no interlacing
# elapsed time     : 0.002001523971557617 seconds
#
# file 137/176
# target file      : "test input\s37i3p04.png"
# test description : 37x37 paletted file, interlaced
# elapsed time     : 0.003000020980834961 seconds
#
# file 138/176
# target file      : "test input\s37n3p04.png"
# test description : 37x37 paletted file, no interlacing
# elapsed time     : 0.003997087478637695 seconds
#
# file 139/176
# target file      : "test input\s38i3p04.png"
# test description : 38x38 paletted file, interlaced
# elapsed time     : 0.0029976367950439453 seconds
#
# file 140/176
# target file      : "test input\s38n3p04.png"
# test description : 38x38 paletted file, no interlacing
# elapsed time     : 0.0030002593994140625 seconds
#
# file 141/176
# target file      : "test input\s39i3p04.png"
# test description : 39x39 paletted file, interlaced
# elapsed time     : 0.0020973682403564453 seconds
#
# file 142/176
# target file      : "test input\s39n3p04.png"
# test description : 39x39 paletted file, no interlacing
# elapsed time     : 0.003009796142578125 seconds
#
# file 143/176
# target file      : "test input\s40i3p04.png"
# test description : 40x40 paletted file, interlaced
# elapsed time     : 0.0030088424682617188 seconds
#
# file 144/176
# target file      : "test input\s40n3p04.png"
# test description : 40x40 paletted file, no interlacing
# elapsed time     : 0.0035049915313720703 seconds
#
# file 145/176
# target file      : "test input\tbbn0g04.png"
# test description : not documented
# elapsed time     : 0.002005338668823242 seconds
#
# file 146/176
# target file      : "test input\tbbn2c16.png"
# test description : transparent, blue background chunk
# elapsed time     : 0.0029947757720947266 seconds
#
# file 147/176
# target file      : "test input\tbbn3p08.png"
# test description : transparent, black background chunk
# elapsed time     : 0.0029964447021484375 seconds
#
# file 148/176
# target file      : "test input\tbgn2c16.png"
# test description : transparent, green background chunk
# elapsed time     : 0.004006385803222656 seconds
#
# file 149/176
# target file      : "test input\tbgn3p08.png"
# test description : not documented
# elapsed time     : 0.004524707794189453 seconds
#
# file 150/176
# target file      : "test input\tbrn2c08.png"
# test description : transparent, red background chunk
# elapsed time     : 0.0030007362365722656 seconds
#
# file 151/176
# target file      : "test input\tbwn0g16.png"
# test description : not documented
# elapsed time     : 0.0025103092193603516 seconds
#
# file 152/176
# target file      : "test input\tbwn3p08.png"
# test description : transparent, white background chunk
# elapsed time     : 0.0040035247802734375 seconds
#
# file 153/176
# target file      : "test input\tbyn3p08.png"
# test description : transparent, yellow background chunk
# elapsed time     : 0.0039975643157958984 seconds
#
# file 154/176
# target file      : "test input\tm3n3p02.png"
# test description : not documented
# elapsed time     : 0.0019998550415039062 seconds
#
# file 155/176
# target file      : "test input\tp0n0g08.png"
# test description : not documented
# elapsed time     : 0.002999544143676758 seconds
#
# file 156/176
# target file      : "test input\tp0n2c08.png"
# test description : not transparent for reference (logo on gray)
# elapsed time     : 0.002002239227294922 seconds
#
# file 157/176
# target file      : "test input\tp0n3p08.png"
# test description : not transparent for reference (logo on gray)
# elapsed time     : 0.0021982192993164062 seconds
#
# file 158/176
# target file      : "test input\tp1n3p08.png"
# test description : transparent, but no background chunk
# elapsed time     : 0.0031976699829101562 seconds
#
# file 159/176
# target file      : "test input\xc1n0g08.png"
# test description : not documented
# elapsed time     : 0.001222848892211914 seconds
#
# file 160/176
# target file      : "test input\xc9n2c08.png"
# test description : not documented
# elapsed time     : 0.0015048980712890625 seconds
#
# file 161/176
# target file      : "test input\xcrn0g04.png"
# test description : added cr bytes
# elapsed time     : 0.00099945068359375 seconds
#
# file 162/176
# target file      : "test input\xcsn0g01.png"
# test description : not documented
# elapsed time     : 0.0030007362365722656 seconds
#
# file 163/176
# target file      : "test input\xd0n2c08.png"
# test description : not documented
# elapsed time     : 0.0020236968994140625 seconds
#
# file 164/176
# target file      : "test input\xd3n2c08.png"
# test description : not documented
# elapsed time     : 0.0031812191009521484 seconds
#
# file 165/176
# target file      : "test input\xd9n2c08.png"
# test description : not documented
# elapsed time     : 0.0030493736267089844 seconds
#
# file 166/176
# target file      : "test input\xdtn0g01.png"
# test description : not documented
# elapsed time     : 0.0010001659393310547 seconds
#
# file 167/176
# target file      : "test input\xhdn0g08.png"
# test description : not documented
# elapsed time     : 0.0020051002502441406 seconds
#
# file 168/176
# target file      : "test input\xlfn0g04.png"
# test description : converted cr bytes to lf and removed all NULs
# elapsed time     : 0.2934105396270752 seconds
#
# file 169/176
# target file      : "test input\xs1n0g01.png"
# test description : not documented
# elapsed time     : 0.0034317970275878906 seconds
#
# file 170/176
# target file      : "test input\xs2n0g01.png"
# test description : not documented
# elapsed time     : 0.0034766197204589844 seconds
#
# file 171/176
# target file      : "test input\xs4n0g01.png"
# test description : not documented
# elapsed time     : 0.002287149429321289 seconds
#
# file 172/176
# target file      : "test input\xs7n0g01.png"
# test description : not documented
# elapsed time     : 0.002102375030517578 seconds
#
# file 173/176
# target file      : "test input\z00n2c08.png"
# test description : color, no interlacing, compression level 0 (none)
# elapsed time     : 0.002504587173461914 seconds
#
# file 174/176
# target file      : "test input\z03n2c08.png"
# test description : color, no interlacing, compression level 3
# elapsed time     : 0.0019986629486083984 seconds
#
# file 175/176
# target file      : "test input\z06n2c08.png"
# test description : color, no interlacing, compression level 6 (default)
# elapsed time     : 0.0009987354278564453 seconds
#
# file 176/176
# target file      : "test input\z09n2c08.png"
# test description : color, no interlacing, compression level 9 (maximum)
# elapsed time     : 0.0011560916900634766 seconds
#
# =================================================
# some stats:
#   - total file parsed   : 176
#   - inferred total size : 99926 bytes
#   - total elapsed time  : 0.9401726722717285 seconds

# %% [markdown]
# ## Appendix: File Flush Results Test

# %%
def checksum_fixed_buf_s(fp, hash_algo, buf_size=None):
    with open(fp, 'rb') as fo:
        while True:
            if not buf_size:
                d = fo.read()
            else:
                d = fo.read(buf_size)
            if not d:
                break
            hash_algo.update(d)

def splice_iterable(nonmutable_iterable, length):
    t = []
    while nonmutable_iterable:
        a, nonmutable_iterable = nonmutable_iterable[:length], nonmutable_iterable[length:]
        t.append(a)
    return t


if TEST_FLUSH_TO_FS and STD_TEST_INPUT_TEST:
    import hashlib, subprocess

    perf_hash_algo = hashlib.sha1 # or sha1, md5, and many more within hashlib.algorithms_available,
                                  # preferably hashlib.algorithms_guaranteed

    buf_size = 0xffff

    test_files = list(Path(STD_TEST_INPUT_FOLDER).glob('*.png'))
    output_files = list(Path(TEST_FLUSH_FOLDER).glob('*.png'))

    def fetch_name(o: Path): return o.name
    def intersect(a: list, b: list): return list(filter(lambda x: fetch_name(x) in map(fetch_name, b), a))

    output_files, test_files = intersect(output_files, test_files), intersect(test_files, output_files)

    for n, t in enumerate(test_files):
        o = output_files[n]

        t_h = perf_hash_algo()
        o_h = perf_hash_algo()

        checksum_fixed_buf_s(t, t_h, buf_size=buf_size)
        checksum_fixed_buf_s(o, o_h, buf_size=buf_size)

        if not t_h.digest() == o_h.digest(): 
            print(f'test file "{t}" and flush output file "{o}" hash does not match -> test desc: {parse_png_test_fname_preset(t.name)}')
            # for i in difflib.diff_bytes(
            #         difflib.unified_diff, 
            #         splice_iterable(t.read_bytes(), 4), 
            #         splice_iterable(o.read_bytes(), 4)
            #     ):
            #     if i.startswith(b'+') or i.startswith(b'-'):
            #         print(i)
# Out:
# test file "test input\ccwn2c08.png" and flush output file "export\ccwn2c08.png" hash does not match -> test desc: chroma chunk w:0.3127,0.3290 r:0.64,0.33 g:0.30,0.60 b:0.15,0.06
# test file "test input\ccwn3p08.png" and flush output file "export\ccwn3p08.png" hash does not match -> test desc: chroma chunk w:0.3127,0.3290 r:0.64,0.33 g:0.30,0.60 b:0.15,0.06
# test file "test input\exif2c08.png" and flush output file "export\exif2c08.png" hash does not match -> test desc: not documented
# test file "test input\tbbn0g04.png" and flush output file "export\tbbn0g04.png" hash does not match -> test desc: not documented
# test file "test input\tbrn2c08.png" and flush output file "export\tbrn2c08.png" hash does not match -> test desc: transparent, red background chunk
# test file "test input\xc9n2c08.png" and flush output file "export\xc9n2c08.png" hash does not match -> test desc: not documented
# test file "test input\xcsn0g01.png" and flush output file "export\xcsn0g01.png" hash does not match -> test desc: not documented
# test file "test input\xd0n2c08.png" and flush output file "export\xd0n2c08.png" hash does not match -> test desc: not documented
# test file "test input\xd3n2c08.png" and flush output file "export\xd3n2c08.png" hash does not match -> test desc: not documented
# test file "test input\xd9n2c08.png" and flush output file "export\xd9n2c08.png" hash does not match -> test desc: not documented
# test file "test input\xhdn0g08.png" and flush output file "export\xhdn0g08.png" hash does not match -> test desc: not documented
# test file "test input\xlfn0g04.png" and flush output file "export\xlfn0g04.png" hash does not match -> test desc: converted cr bytes to lf and removed all NULs
